# %% [markdown]
# # GenAI Transcript Analysis
# ## Project Overview
# This notebook is for analyzing call transcripts using generative AI to detect fraud patterns and customer sentiment.
#
# ## Initial Setup
# - Created on: July 05, 2025
# - Author: Shubhadeep Das
# - Objective: Prototype fraud detection using transcript data.
# - Update API Key: Nov 22, 2025

# %%
# Import essential libraries
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
load_dotenv()

# Placeholder for future code
print('Hello, GenAI Transcript Project!')
# Out:
# Hello, GenAI Transcript Project!

# %% [markdown]
# # GenAI Transcript Project
# ## Prompt Input/Output with Google Gemini API (Free)
# - **Created on**: July 05, 2025
# - **Author**: Shubhadeep Das
# - **Objective**: Generate text from user prompts using Google's Gemini API (free tier).
# - **Future Scope**: Integrate transcript data, fine-tune models, or scale with Google Cloud.
# - **Update**: API Key updated on Nov 22, 2025

# %% [markdown]
# # Install required library (run once in your environment)
# !pip install -U google-generativeai

# %%
# Import necessary modules
import google.generativeai as genai

# %%
# Set your Gemini API key (get from https://aistudio.google.com)
GOOGLE_API_KEY = os.getenv('GEMINI_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
# Initialize the Gemini model
model_1 = genai.GenerativeModel('gemini-1.5-flash')  # Free-tier model discontinued
model_2 = genai.GenerativeModel('gemini-2.5-flash')  # Free-tier model

# %%
def chat(prompt, model):
    # Generate text
    response = model.generate_content(prompt, generation_config={
        'max_output_tokens': 1500,
        'temperature': 0.7
    })
    
    # Return the generated text
    return response.text.strip()

# %% [markdown]
# print(chat("Tell me something about yourself", model_1))

# %%
print(chat("Tell me something about yourself", model_2))
# Out:
# I am a large language model, trained by Google.
#
# My main purpose is to assist users like you by providing information, answering questions, generating text, and engaging in helpful conversations. I don't have personal experiences, feelings, or consciousness, but I can process and understand a vast amount of information to communicate with you effectively.

# %% [markdown]
# print(chat("Generate a call transcript between a bank agent and a customer who got defrauded", model_1))

# %%
pmt = "Generate a call transcript between a bank agent and a customer who got defrauded"

# %%
response = model_2.generate_content(pmt, generation_config={
    'max_output_tokens': 5000,
    'temperature': 0.7
})
print(response.text.strip())
# Out:
# ## Call Transcript: Fraud Report
#
# **Characters:**
#
# *   **Sarah:** Bank Agent, calm, empathetic, professional.
# *   **Mr. Henderson:** Customer, distressed, confused, feeling foolish.
#
# **(Call begins)**
#
# **Sarah:** Thank you for calling Evergreen Bank, my name is Sarah, how can I help you today?
#
# **Mr. Henderson:** (Voice trembling, agitated) Sarah, I need help. I think... I think I've been defrauded. I've lost everything!
#
# **Sarah:** Oh dear, Mr. Henderson, I'm so sorry to hear that. Please take a deep breath. We're here to help you. First, for security, could you please confirm your full name and date of birth for me?
#
# **Mr. Henderson:** (Struggling to steady his voice) Yes, it's Robert Henderson. H-E-N-D-E-R-S-O-N. And my date of birth is June 14th, 1968.
#
# **Sarah:** Thank you, Mr. Henderson. And can you also confirm the last four digits of your social security number?
#
# **Mr. Henderson:** It's XXXX.
#
# **Sarah:** Thank you for confirming, Mr. Henderson. Now, please tell me what happened, in as much detail as you can. Take your time.
#
# **Mr. Henderson:** (Sighs heavily) It started yesterday. I got an email, it looked exactly like it was from Microsoft. It said there was suspicious activity on my computer, and to call a number immediately. I was worried, you know? My computer has been acting a bit slow.
#
# **Sarah:** I understand. And did you call that number?
#
# **Mr. Henderson:** Yes, I did. A man answered, very professional. He said he was from Microsoft support. He told me to go to a website, and then he asked me to download some software so he could "remotely access" my computer to fix the issue. He said my computer was infected with a serious virus.
#
# **Sarah:** Okay, so you gave him remote access to your computer. What happened next?
#
# **Mr. Henderson:** He was on my computer for a while, making things pop up, showing me all these scary warnings. He said my bank accounts were compromised because of the virus, and that my money wasn't safe. He told me I needed to immediately transfer all my funds to a "secure government holding account" to protect them, and that they'd be returned to me in 48 hours.
#
# **Sarah:** And did you make that transfer, Mr. Henderson?
#
# **Mr. Henderson:** (Voice cracking) Yes. He stayed on the phone, guiding me through my online banking. He even had me read out the codes I got on my phone. I transferred... I transferred forty-five thousand dollars. My entire life savings. To an account he gave me. He said it was a wire transfer for security.
#
# **Sarah:** (Calmly) I see. Mr. Henderson, this sounds like a very common and sophisticated "tech support" or "impersonation" scam. I'm so sorry this happened to you. Can you tell me exactly when you initiated that wire transfer?
#
# **Mr. Henderson:** It was yesterday afternoon, around 3 PM Eastern Time.
#
# **Sarah:** And do you have the details of the recipient account? The name of the bank, the account number, and the name of the recipient they gave you?
#
# **Mr. Henderson:** (Rustling paper) Yes, I wrote it down. It was to an account at "Global Trust Bank," account number XXXXXXXXXX, and the name was "Secure Holdings LLC."
#
# **Sarah:** Thank you for that information, Mr. Henderson. The first thing we need to do is secure your remaining accounts with us, just in case. I'm going to immediately place a temporary freeze on your checking and any other savings accounts you have, and we'll reset your online banking password. I'll send you a temporary password via text message to your registered phone number right now. Please do not use your computer for banking until it's been professionally cleaned or reset.
#
# **Mr. Henderson:** (Sounding a little less frantic) Okay... okay, thank you.
#
# **Sarah:** Now, regarding the wire transfer. I need to be transparent with you, Mr. Henderson. Wire transfers are often irreversible once they've been sent and received, especially if the funds have already been moved by the recipient. However, we will initiate a recall request immediately with Global Trust Bank. The chances of success depend entirely on how quickly they can act and if the funds are still in that recipient account. I'll open a fraud investigation case for you right now. The reference number for this will be FRD-2024-XXXXX.
#
# **Mr. Henderson:** So... so it's gone? My money is just gone?
#
# **Sarah:** We are doing everything we can, Mr. Henderson. I will submit the recall request right away, but it's important to prepare for the possibility that the funds may not be recoverable. These scammers are very quick to move money once they receive it.
#
# **Mr. Henderson:** Oh god...
#
# **Sarah:** Beyond what we're doing here, there are a few critical steps you need to take as soon as possible.
#
# **Mr. Henderson:** What steps?
#
# **Sarah:** First, you need to file a police report. This is crucial for official documentation of the crime. They may not be able to recover your money either, but it's an essential step in any fraud case.
#
# **Mr. Henderson:** The police?
#
# **Sarah:** Yes. Second, because you gave them remote access to your computer and potentially your banking details, you should contact the three major credit bureaus – Experian, Equifax, and TransUnion – and place a fraud alert on your credit file. This will help protect you against potential identity theft. I can provide you with their contact information.
#
# **Mr. Henderson:** Identity theft too? This is a nightmare.
#
# **Sarah:** I know this is overwhelming, Mr. Henderson, but taking these steps will help protect you further. Also, I highly recommend changing passwords on *all* your important online accounts – email, social media, shopping sites – not just your banking. And as I mentioned, please have your computer professionally checked for malware or consider resetting it to factory settings.
#
# **Mr. Henderson:** I feel so stupid, Sarah. How could I have fallen for this?
#
# **Sarah:** Mr. Henderson, please don't blame yourself. These scammers are incredibly sophisticated and manipulative. They prey on people's trust and fear, and they sound very convincing. Many, many people fall victim to these types of scams. You are not alone in this.
#
# **Mr. Henderson:** (A little calmer) Thank you, Sarah.
#
# **Sarah:** I've documented everything thoroughly. You'll receive an email shortly with a summary of the steps we've taken today, the fraud investigation reference number, and a list of the actions you need to take, along with contact information for the credit bureaus and fraud prevention resources. We will keep you updated on the status of the wire transfer recall request. Please allow up to 5-7 business days for an initial response from Global Trust Bank.
#
# **Mr. Henderson:** Okay. Thank you, Sarah. I really appreciate your help.
#
# **Sarah:** You're very welcome, Mr. Henderson. Please don't hesitate to call us back if you have any more questions or remember any additional details. We're here to support you through this. Is there anything else I can assist you with right now?
#
# **Mr. Henderson:** No, I think that's it for now. Thank you.
#
# **Sarah:** Thank you for calling Evergreen Bank. Have a safe day.
#
# **(Call ends)**
